# %% [markdown]
# # Sentiment Analysis Demo
#
# Run the cell below to analyze sentiment.

# %%
import main

# Edit these test cases and rerun the cell
test_texts = [
    "Launchables make sharing AI work so easy!",
    "Setup took forever and nothing worked.",
    "The tutorial is clear and examples run perfectly.",
]

main.analyze_sentiment(test_texts)
